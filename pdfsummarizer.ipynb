# %%
import time

import numpy as np
import tensorflow as tf

import utils

from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

# %%
dataset_folder_path = 'dataset.txt'

# %%
with open('dataset') as f:
    text = f.read()

# %%
text
# Out:
# 'INDIAN WATER QUALITY TRACKING AND PREDICTION USING WSN AND MACHINE LEARNING\nSubmitted in partial fulfillment for the award of the degree of\nMaster of Computer Application  \nby\nANBARIVAN N.L (17MCA0263)\n\n\n\n\n\n\n\n\nSCHOOL OF INFORMATION TECHNOLOGY AND ENGINEERING\n\nApril,2019 \n\nINDIAN WATER QUALITY TRACKING AND PREDICTION USING WSN AND MACHINE LEARNING \nSubmitted in partial fulfillment for the award of the degree of\n \nMaster of Computer Application  \n\n\nby\n \nANBARIVAN N.L (17MCA0263)\n\n\n\n\n\n\nSCHOOL OF INFORMATION TECHNOLOGY AND ENGINEERING\n\n\nApril,2019\n\nDECLARATION\n\n\tI hereby declare that the thesis entitled “INDIAN WATER QUALITY TRACKING AND PREDICTION USING WSN AND MACHINE LEARNING” submitted by me, for the award of the degree of Specify the name of the degree VIT is a record of bonafide work carried out by me under the supervision of  Prof. Siva Rama Krishnan S\n\tI further declare that the work reported in this thesis has not been submitted and wil
# ...

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

from gensim.summarization import summarize

# %%
summarize(text)
# Out:
# 2019-04-15 21:24:36,656 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-04-15 21:24:36,663 : INFO : built Dictionary(1007 unique tokens: ['toxic', 'senor', 'head', 'vit', 'score']...) from 516 documents (total 3240 corpus positions)
# 2019-04-15 21:24:36,668 : INFO : Building graph
# 2019-04-15 21:24:36,669 : INFO : Filling graph
# 2019-04-15 21:24:36,828 : INFO : Removing unreachable nodes of graph
# 2019-04-15 21:24:36,830 : INFO : Pagerank graph
# 2019-04-15 21:24:36,876 : INFO : Sorting pagerank scores
# ...

# %%
#Use the "split" option if you want a list of strings instead of a single string.
summarize(text, split=True)
# Out:
# 2019-04-15 21:24:38,079 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-04-15 21:24:38,089 : INFO : built Dictionary(1007 unique tokens: ['toxic', 'senor', 'head', 'vit', 'score']...) from 516 documents (total 3240 corpus positions)
# 2019-04-15 21:24:38,098 : INFO : Building graph
# 2019-04-15 21:24:38,100 : INFO : Filling graph
# 2019-04-15 21:24:38,266 : INFO : Removing unreachable nodes of graph
# 2019-04-15 21:24:38,268 : INFO : Pagerank graph
# 2019-04-15 21:24:38,317 : INFO : Sorting pagerank scores
# ['INDIAN WATER QUALITY TRACKING AND PREDICTION USING WSN AND MACHINE LEARNING ',
#  'INDIAN WATER QUALITY TRACKING AND PREDICTION USING WSN AND MACHINE LEARNING ',
#  'I hereby declare that the thesis entitled “INDIAN WATER QUALITY TRACKING AND PREDICTION USING WSN AND MACHINE LEARNING” submitted by me, for the award of the degree of Specify the name of the degree VIT is a record of bonafide work carried out by me under the supervision of  Prof.',
# ...

# %%
#You can adjust how much text the summarizer outputs via the "ratio" parameter or the "word_count" parameter. 
#Using the "ratio" parameter, you specify what fraction of sentences in the original text should be returned 
#as output. Below we specify that we want 50% of the original text (the default is 20%).
summarize(text, ratio=0.5)
# Out:
# 2019-04-15 21:24:39,234 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-04-15 21:24:39,242 : INFO : built Dictionary(1007 unique tokens: ['toxic', 'senor', 'head', 'vit', 'score']...) from 516 documents (total 3240 corpus positions)
# 2019-04-15 21:24:39,246 : INFO : Building graph
# 2019-04-15 21:24:39,248 : INFO : Filling graph
# 2019-04-15 21:24:39,404 : INFO : Removing unreachable nodes of graph
# 2019-04-15 21:24:39,407 : INFO : Pagerank graph
# 2019-04-15 21:24:39,457 : INFO : Sorting pagerank scores
# ...

# %%
summarize(text, word_count=200)
# Out:
# 2019-04-15 21:24:40,360 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-04-15 21:24:40,366 : INFO : built Dictionary(1007 unique tokens: ['toxic', 'senor', 'head', 'vit', 'score']...) from 516 documents (total 3240 corpus positions)
# 2019-04-15 21:24:40,372 : INFO : Building graph
# 2019-04-15 21:24:40,373 : INFO : Filling graph
# 2019-04-15 21:24:40,539 : INFO : Removing unreachable nodes of graph
# 2019-04-15 21:24:40,541 : INFO : Pagerank graph
# 2019-04-15 21:24:40,587 : INFO : Sorting pagerank scores
# ...

# %%
from gensim.summarization import keywords

keywords(text)
# Out:
# 'figures\nfigure\ndata\nwater\nnetworks\nnetwork\nnetworking\nfunction\nfunctional\nfunctionality\nsensors\nsensor\npollution\npollutants\nrouting\nroute\nproblem\nvalue\nvalues\nieee\npaper\nmodel\nmodels\nprotocols\nenergy costs\noptimization problems\nissues\nissue\nresearch\ngradient descent\nfunctions slope\nquality\ntechnique\ntechniques\nbase\nindexes\nindexed\nwork\nworking\nworks\ninformation\nincludes\ninclude\nprotocol called\ninternal\ninterner\ninternational\ntime\ntimes\npollutant concentration levels\ncommunities\ncommunication\ncommunicates\ncommunications\noptimized\noptimal\noptimize\npoint\npoints\nparameters\nparameter\ncalculated\ncalculate\ncalculates\nclusters\nclustering\ncluster\nclustered\ntables\ntable\nperformance\nperformed\nchanging\nchanges\nchange\nchanged\ncost\nclass\nclasses\nwqi\ncalculating individual index\nefficiency\nlearning\nlearn\nlogistic regression\nwireless\nrate\nrates\nrating\nscale\nscaling\nscaled\nalgorithms perform\nweight based nod
# ...

# %%
keywords(text, ratio=0.01)
# Out:
# 'figures\nfigure\ndata\nwater\nnetworks\nnetwork\nnetworking\nfunction\nfunctional\nfunctionality\nfunctions\nsensors\nsensor\npollution\npollutant\npollutants\nenergy'
